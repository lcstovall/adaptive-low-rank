# %%
import importlib
import pickle

import adaptive_low_rank.plotting as plotting

importlib.reload(plotting)

with open("../results/runtime_scaling/runtime_scaling.pkl", "rb") as file:
    results = pickle.load(file)

plotting.plot_runtime_scaling(
    results,
    output_dir="../figures",
    fixed_d=100,
    name="runtime_scaling_fixed_d100",
)

# %%
import importlib
import pickle

import adaptive_low_rank.plotting as plotting

importlib.reload(plotting)

with open("../results/runtime_scaling/runtime_scaling.pkl", "rb") as file:
    results = pickle.load(file)

plotting.plot_runtime_scaling(
    results,
    output_dir="../figures",
    fixed_n=10_000,
    name="runtime_scaling_fixed_n10000",
)
