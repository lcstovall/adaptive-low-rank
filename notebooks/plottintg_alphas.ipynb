# %%
from pathlib import Path
import pickle
from adaptive_low_rank.plotting import plot_alphas
import yaml

# Load the alpha experiment results.
results_dir = Path("../results/interactions_alpha")

with (results_dir / "results.pkl").open("rb") as file:
    results = pickle.load(file)

with (results_dir / "config.yml").open() as file:
    name = yaml.safe_load(file)["dataset"]

# Plot the learned alpha values.
plot_alphas(results, "../figures/", name)

# %%
# Load the alpha experiment results.
results_dir = Path("../results/yearprediction_alpha")

with (results_dir / "results.pkl").open("rb") as file:
    results = pickle.load(file)

with (results_dir / "config.yml").open() as file:
    name = yaml.safe_load(file)["dataset"]

# Plot the learned alpha values.
plot_alphas(results, "../figures/", name)
