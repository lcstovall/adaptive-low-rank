# %%
from pathlib import Path
import pickle
from adaptive_low_rank.plotting import plot_alphas

results_dir = Path("../results/interactions_alpha")
with (results_dir / "results.pkl").open("rb") as file:
    results = pickle.load(file)

plot_alphas(results, "../figures/")

# %%
first_alpha_values = [entry["result"].alphas[0] for entry in results]

for value in first_alpha_values:
    print(value)
# Out:
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
# 0.1234836060140756
# 0.13206963501173496
# 0.13309242082268824
# 0.13315252419737433
